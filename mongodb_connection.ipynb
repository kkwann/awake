# %%
import pymongo
import pandas as pd

import os
from dotenv import load_dotenv

# %%
# .env 파일에서 환경 변수 로드
load_dotenv('C:/py_src/awake/env')

# 환경 변수에서 MongoDB 연결 정보 가져오기
mongo_password = os.getenv('MONGO_PASSWORD')
mongo_user = os.getenv('MONGO_USER')

# %%
# MongoDB 연결 URL
url = f"mongodb+srv://{mongo_user}:{mongo_password}@meercat-external.udyfs.mongodb.net/?retryWrites=true&w=majority&appName=meercat-external"
client = pymongo.MongoClient(url, serverSelectionTimeoutMS=100000)

# %%
# 연결 확인
from pymongo.errors import ServerSelectionTimeoutError

try:
    # 데이터베이스 목록을 가져오는 쿼리
    databases = client.list_database_names()
    print("Connected successfully. Databases:", databases)
    
except ServerSelectionTimeoutError as err:
    print("Connection failed:", err)
# Out:
# Connected successfully. Databases: ['Test', 'admin', 'config', 'local']

# %%
# 데이터베이스 확인
client.list_database_names()
# Out:
# ['Test', 'admin', 'config', 'local']

# %%
# Test DB 선택
db = client.Test

# Test DB 컬렉션 확인
collections = db.list_collection_names()

# %%
# 인스타 관련 데이터 제외 --> 'youtube_videos' 따로 확인
collections_need = [
    'hashtag_hashtag',
    'youtube_revenue',
    'youtube_report_v2',
    # 'influencer_datas',
    'youtube_channel_demographics',
    'user_aggregations',
    'campaign_bookmarks',
    # 'youtube_videos',
    'hashtag_hashtaglog',
    'youtube_report',
    'youtube_users',
    'alpha_tests',
    # 'influencer_media_datas',
    'youtube_channel_locations',
    'youtube_daily_channel_basics',
    # 'influencer_media_comments',
    'user_bookmarks',
    'youtube_subscriber',
    'campaigns',
    'youtube_datas',
    # 'instagram_stories'
    ]

# %%
# 단위 환산
def convert_bytes(num):
    for x in ['bytes', 'KB', 'MB', 'GB', 'TB']:
        if num < 1024.0:
            return f"{num:.2f} {x}"
        num /= 1024.0

# %%
for collection_name in collections:
    # 컬렉션 통계 정보 가져오기
    stats = db.command("collStats", collection_name)

    # 컬렉션의 크기와 문서 수 출력    
    print(f"Collection '{collection_name}' size: {convert_bytes(stats['size'])}")
    print(f"Collection '{collection_name}' document count: {stats['count']}")
    print(f"Total index size: {convert_bytes(stats['totalIndexSize'])}")
    print('--------------------------------------------------------------------')
# Out:
# Collection 'hashtag_hashtag' size: 13.39 MB
# Collection 'hashtag_hashtag' document count: 3052
# Total index size: 172.00 KB
# --------------------------------------------------------------------
# Collection 'youtube_revenue' size: 259.47 MB
# Collection 'youtube_revenue' document count: 811499
# Total index size: 46.44 MB
# --------------------------------------------------------------------
# Collection 'youtube_report_v2' size: 4.60 MB
# Collection 'youtube_report_v2' document count: 5303
# Total index size: 484.00 KB
# --------------------------------------------------------------------
# Collection 'influencer_datas' size: 7.78 GB
# Collection 'influencer_datas' document count: 3340624
# Total index size: 246.63 MB
# --------------------------------------------------------------------
# Collection 'youtube_channel_demographics' size: 59.67 MB
# Collection 'youtube_channel_demographics' document count: 297683
# Total index size: 4.69 MB
# --------------------------------------------------------------------
# Collection 'user_aggregations' size: 30.61 MB
# Collection 'user_aggregations' document count: 31597
# Total index size: 8.33 MB
# --------------------------------------------------------------------
# Collection 'campaign_bookmarks' size: 2.49 KB
# Collection 'campaign_bookmarks' document count: 26
# Total index size: 36.00 KB
# --------------------------------------------------------------------
# Collection 'youtube_videos' size: 8.33 GB
# Collection 'youtube_videos' document count: 302054
# Total index size: 124.73 MB
# --------------------------------------------------------------------
# Collection 'hashtag_hashtaglog' size: 9.15 KB
# Collection 'hashtag_hashtaglog' document count: 142
# Total index size: 72.00 KB
# --------------------------------------------------------------------
# Collection 'youtube_report' size: 3.50 MB
# Collection 'youtube_report' document count: 3560
# Total index size: 104.00 KB
# --------------------------------------------------------------------
# Collection 'youtube_users' size: 2.27 MB
# Collection 'youtube_users' document count: 938
# Total index size: 3.97 MB
# --------------------------------------------------------------------
# Collection 'alpha_tests' size: 11.98 MB
# Collection 'alpha_tests' document count: 9675
# Total index size: 932.00 KB
# --------------------------------------------------------------------
# Collection 'influencer_media_datas' size: 206.01 GB
# Collection 'influencer_media_datas' document count: 3368632
# Total index size: 2.96 GB
# --------------------------------------------------------------------
# Collection 'youtube_channel_locations' size: 222.80 MB
# Collection 'youtube_channel_locations' document count: 297394
# Total index size: 5.21 MB
# --------------------------------------------------------------------
# Collection 'youtube_daily_channel_basics' size: 607.24 MB
# Collection 'youtube_daily_channel_basics' document count: 906
# Total index size: 128.00 KB
# --------------------------------------------------------------------
# Collection 'influencer_media_comments' size: 0.00 bytes
# Collection 'influencer_media_comments' document count: 0
# Total index size: 28.00 KB
# --------------------------------------------------------------------
# Collection 'user_bookmarks' size: 2.39 KB
# Collection 'user_bookmarks' document count: 26
# Total index size: 36.00 KB
# --------------------------------------------------------------------
# Collection 'youtube_subscriber' size: 610.81 MB
# Collection 'youtube_subscriber' document count: 3035474
# Total index size: 227.23 MB
# --------------------------------------------------------------------
# Collection 'campaigns' size: 4.49 MB
# Collection 'campaigns' document count: 84
# Total index size: 36.00 KB
# --------------------------------------------------------------------
# Collection 'youtube_datas' size: 1.11 GB
# Collection 'youtube_datas' document count: 406522
# Total index size: 21.75 MB
# --------------------------------------------------------------------
# Collection 'instagram_stories' size: 1.68 GB
# Collection 'instagram_stories' document count: 1825129
# Total index size: 105.08 MB
# --------------------------------------------------------------------

# %%
# for document in db['youtube_videos'].find().batch_size(1000):
#     # 각 문서에 대한 처리
#     print(document)

# %%
aa = pd.DataFrame(list(db['youtube_datas'].find().skip(0).limit(100)))

# %%
aa[aa.columns[:20]]
# Out:
#                          _id  subscriber_count  video_count  view_count  \
# 0   627dd732c0dfe30fc1abe9e1              5390            8          62
# 1   627dd732c0dfe30fc1abe9e3            108000           30        4354
# 2   627dd736c0dfe30fc1abe9e5                 0            0           0
# 3   627dd736c0dfe30fc1abe9e7                 0            0           0
# 4   627f0d23aa39226247c5f263               116            1           4
# ..                       ...               ...          ...         ...
# 95  628847a5fb15712a8cbb0c3d                28            1           1
# 96  628847a5fb15712a8cbb0c3f                 7            4           0
# 97  628847a5fb15712a8cbb0c41               193           17           1
# 98  628847a5fb15712a8cbb0c43                16           14           0
# 99  628847a5fb15712a8cbb0c45                 6            0           0
#
#     comment_count  like_count  dislike_count  estimated_minutes_watched  \
# 0               0           0              0                         61
# 1               0          41             -1                      24735
# 2               0           0              0                          0
# 3               0           0              0                          0
# 4               0           0              0                          3
# ..            ...         ...            ...                        ...
# 95              0           0              0                          0
# 96              0           0              0                          0
# 97              0           0              0                          0
# 98              0           0              0                          0
# 99              0           0              0                          0
#
#     average_view_duration           youtube_user_id          kakao_account_id  \
# 0                      59  627c8fdbce0b951b01262140  60937cd098670f5d30a17022
# 1                     340  627cb611aa6f212355e0b617  627cb5f6aa6f212355e0b5b4
# 2                       0  627cd09faa6f212355e14268  615904dfbc9b4840b3f35221
# 3                       0  627b58c880a4763fdf8e13de  625686fee63da410fc853f66
# 4                      57  627deb73aa39226247c461a1  629d2745eaf5732d6decbdc3
# ..                    ...                       ...                       ...
# 95                     46  628722e8fb15712a8cb932a4  628722dbfb15712a8cb93293
# 96                      0  62879fa5fb15712a8cbb0958  626cbe4a3f804b323362dfee
# 97                     49  62810d9eaa39226247c994f2  62810cc2aa39226247c994e4
# 98                      0  6287efb5fb15712a8cbb0af1  620bb39df6653147defaed3d
# 99                      0  628728defb15712a8cb93569  6086350fdb71a410db5ea6f8
#
#                   channel_id     channel_title  \
# 0   UCqvom1WpXg0ueWiv2qDJflA        이재이Lee Jay
# 1   UCxuEudcvmg4zMQhW7isWi-w          성팩 SPAAK
# 2   UCe144H51UZ7XYEmAV204QdA               박효진
# 3   UCVon3pofMxnCdelBNr6PQ-g              갱배고파
# 4   UC7lPLG5gKr5PSMqAkSfhJWA               김민준
# ..                       ...               ...
# 95  UCteqWzsri8RJ4QZW49jnpeQ            Joshua
# 96  UCkIreAMtmXeEu6P3JKVX5AA  퍼플러썸 Purpleossom
# 97  UCFE1HeTKYLhUuErpx72eiSA      유걸YU-Girl TV
# 98  UCeychZVkPmUvAW--avJZ_Ug               아이니
# 99  UCUVnB7cTszM2NKj5SEcaVgQ        Steve Park
#
#                                   channel_description            published_at  \
# 0   안녕하세요! 이재이입니다.\n앞으로 제 유튜브 채널을 통한 그동안 보여드리지 못했던... 2020-05-03 13:30:03.443
# 1   좌충우돌 성팩이의 유튜브! 항상 열심히하겠습니다 구독해주세요 :) \n비즈니스 문의... 2013-07-31 07:43:00.000
# 2                                                     2019-11-13 14:22:44.649
# 3                                                     2018-10-31 07:39:22.000
# 4   안녕하세요, 김민준입니다.\n크리에이터테크 스타트업 '어웨이크코퍼레이션' 을 운영하... 2018-11-06 06:20:14.000
# ..                                                ...                     ...
# 95                                                    2013-10-17 09:47:29.000
# 96                                                    2022-04-15 12:31:35.097
# 97                  그냥 취미로 찍는 일상 유튜브 입니다\n영상 재밌게 봐주세요 2020-07-09 07:21:35.657
# 98                                                    2021-10-10 08:07:31.139
# 99                                                    2015-08-31 02:55:58.000
#
#                                         thumbnail_url  \
# 0   https://yt3.ggpht.com/ytc/AKedOLTFfk60oJI23PC0...
# 1   https://yt3.ggpht.com/L_EHboXUjidjrXFGg2XAmEE9...
# 2   https://yt3.ggpht.com/ytc/AKedOLRO4Dc2UbMRylPo...
# 3   https://yt3.ggpht.com/ytc/AKedOLRS60VXBs6aZfDl...
# 4   https://yt3.ggpht.com/m1j0Pk02oz9Qa0IcGkp2-frf...
# ..                                                ...
# 95  https://yt3.ggpht.com/ytc/AKedOLQCx5U4SQIs4piN...
# 96  https://yt3.ggpht.com/u6U_MssqhiQCdad9EzxlM6DM...
# 97  https://yt3.ggpht.com/u0jTnAEmggwPXV67DycBsRLW...
# 98  https://yt3.ggpht.com/ksK07UumZfHn3O5HzCta3Hkg...
# 99  https://yt3.ggpht.com/ytc/AKedOLSnzLkhU8-8dRjI...
#
#                                   traffic_source_type  \
# 0   {'YT_SEARCH': 44, 'YT_CHANNEL': 10, 'SUBSCRIBE...
# 1   {'RELATED_VIDEO': 2197, 'SUBSCRIBER': 945, 'YT...
# 2                                                 NaN
# 3                                                 NaN
# 4                {'NO_LINK_OTHER': 2, 'YT_SEARCH': 2}
# ..                                                ...
# 95                                   {'YT_SEARCH': 1}
# 96                                                NaN
# 97                                     {'EXT_URL': 1}
# 98                                                NaN
# 99                                                NaN
#
#                                     yt_search_keyword  \
# 0   {'비키니 하울': 7, '한달에 10kg 빼기': 6, '1달만에 10kg빼기':...
# 1   {'성팩': 70, '수빙수': 45, '원칩': 30, '원칩챌린지 먹방': 23...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                               subscribed_status              created_at
# 0         {'UNSUBSCRIBED': 59, 'SUBSCRIBED': 2} 2022-05-13 12:57:34.573
# 1   {'UNSUBSCRIBED': 18476, 'SUBSCRIBED': 6259} 2022-05-13 12:57:34.576
# 2                                           NaN 2022-05-13 12:57:34.579
# 3                                           NaN 2022-05-13 12:57:34.568
# 4                           {'UNSUBSCRIBED': 3} 2022-05-14 11:00:00.212
# ..                                          ...                     ...
# 95                          {'UNSUBSCRIBED': 0} 2022-05-21 11:00:00.772
# 96                                          NaN 2022-05-21 11:00:00.880
# 97                          {'UNSUBSCRIBED': 0} 2022-05-21 11:00:00.745
# 98                                          NaN 2022-05-21 11:00:00.883
# 99                                          NaN 2022-05-21 11:00:00.852
#
# [100 rows x 20 columns]
